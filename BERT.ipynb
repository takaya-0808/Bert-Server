# %%
conda install -c conda-forge transformers
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge mecab
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: -
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                                                  |failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - alabaster -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|3.4.*|>=3.7,<3.8.0a0']
#   - anaconda==2020.11 -> python[version='3.7.9|3.8.5',build='h7579374_1|h7579374_0']
#   - argon2-cffi -> python[version='2.7.*|3.5.*|3.6.*|3.6.12|3.6.12|3.7.10|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|>=3.5,<3.6.0a0|3.4.*|3.7.*|3.9.*|3.8.*',build='0_73_pypy|4_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|5_73_pypy|3_73_pypy|2_73_pypy|1_73_pypy']
#   - atomicwrites -> python[version='2.7.*|3.5.*|3.6.*|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - backports -> python[version='2.7.*|3.5.*|3.6.*|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0']
#   - bkcharts -> python[version='3.4.*|>=3.7.1,<3.8.0a0']
#   - brotlipy -> python[version='3.4.*|3.6.12|3.6.12|3.7.10|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|3.9.*|3.8.*|3.7.*',build='0_73_pypy|4_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|5_73_pypy|3_73_pypy|2_73_pypy|1_73_pypy']
#   - cffi -> python[version='2.7.*|3.5.*|3.6.*|3.6.12|3.6.12|3.7.10|3.7.10|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.9,<3.10.0a0|3.7.9|3.6.9|3.6.9|3.6.9|>=2.7,<2.8.0a0|3.6.9|>=3.5,<3.6.0a0|3.4.*',build='0_73_pypy|4_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|5_73_pypy|3_73_pypy|2_73_pypy|1_73_pypy']
#   - colorama -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - conda-env -> python[version='2.7.*|3.4.*|3.5.*']
#   - cryptography -> python[version='3.4.*|3.6.12|3.6.12|3.7.10|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|3.9.*|3.7.*|3.8.*|>=3.5|<=3.3',build='0_73_pypy|4_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|5_73_pypy|3_73_pypy|2_73_pypy|1_73_pypy']
#   - diff-match-patch -> python[version='2.7.*|3.4.*|3.5.*|3.6.*']
#   - filelock -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - gevent -> python[version='3.4.*|3.6.12|3.6.12|3.7.10|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|3.7.*|3.9.*|3.8.*',build='0_73_pypy|4_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|5_73_pypy|3_73_pypy|2_73_pypy|1_73_pypy']
#   - glob2 -> python[version='2.7.*|3.4.*|3.5.*|3.6.*|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - html5lib -> python[version='2.7.*|3.5.*|3.6.*|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0']
#   - imageio -> python[version='>=3.9,<3.10.0a0']
#   - imagesize -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0']
#   - intervaltree -> python[version='2.7.*|3.5.*|3.6.*']
#   - jdcal -> python[version='2.7.*|3.5.*|3.6.*|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - jsonlines -> python[version='2.7.*|3.5.*|3.6.*']
#   - more-itertools -> python[version='3.4.*|>=3.9,<3.10.0a0']
#   - olefile -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0']
#   - pathtools -> python[version='2.7.*|3.4.*|3.5.*|3.6.*']
#   - pyasn1 -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0']
#   - pycodestyle -> python[version='>=3.9,<3.10.0a0']
#   - pyflakes -> python[version='>=3.9,<3.10.0a0']
#   - pyopenssl -> python[version='>=3.9,<3.10.0a0']
#   - pyparsing -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - pytorch -> python[version='2.7.*|3.5.*|3.6.*|3.6.12|3.6.12|3.7.10|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|3.4.*|3.8.*|>=3.5|3.9.*|3.7.*|>=3.7|>=3.6,<3.7|>=3',build='0_73_pypy|4_73_pypy|5_73_pypy|0_73_pypy|1_73_pypy|5_73_pypy|3_73_pypy|2_73_pypy|1_73_pypy']
#   - requests-oauthlib -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|3.4.*|>=3.7,<3.8.0a0']
#   - rsa -> python[version='2.7.*|3.4.*|3.5.*|3.6.*']
#   - rsa -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - singledispatch -> python[version='>=3.9,<3.10.0a0']
#   - sphinxcontrib-websupport -> python[version='2.7.*|3.5.*|3.6.*|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0']
#   - tifffile -> python[version='>=3.9,<3.10.0a0']
#   - xmltodict -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0']
#   - zict -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - zope.event -> python[version='2.7.*|3.5.*|3.6.*|>=3.5,<3.6.0a0|3.4.*']
#
# Your python: python=3.8
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package gdbm conflicts for:
# importlib-metadata -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# scikit-image -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# sqlalchemy -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# secretstorage -> pypy3.7[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# setuptools -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# kiwisolver -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# conda-verify -> pypy3.7[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# pyzmq -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# python-libarchive-c -> pypy3.7[version='>=7.3.4'] -> gdbm[version='>=1.18,<1.19.0a0']
# entrypoints -> pypy3.6[version='>=7.3.2'] -> gdbm[version='>=1.18,<1.19.0a0']
# numpy -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# argon2-cffi -> pypy3.7[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# ruamel_yaml -> pypy3.6[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# numexpr -> pypy3.7[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# cython -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# pysocks -> pypy3.6[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# ipython -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# yarl -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# jedi -> pypy3.7[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# chardet -> pypy3.6[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# path -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# distributed -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# spyder-kernels -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# pickleshare -> pypy3.6[version='>=7.3.2'] -> gdbm[version='>=1.18,<1.19.0a0']
# keyring -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# pytables -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# pytest -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# matplotlib -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# markupsafe -> pypy3.7[version='>=7.3.4'] -> gdbm[version='>=1.18,<1.19.0a0']
# pycosat -> pypy3.7[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# wrapt -> pypy3.6[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# multidict -> pypy3.6[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# watchdog -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# tokenizers -> pypy3.6[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# certifi -> pypy3.7[version='>=7.3.4'] -> gdbm[version='>=1.18,<1.19.0a0']
# pathlib2 -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# cytoolz -> pypy3.6[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# zope.interface -> pypy3.6[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# cffi -> pypy3.7=7.3.5 -> gdbm[version='>=1.18,<1.19.0a0']
# gevent -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# beautifulsoup4 -> pypy3.6[version='>=7.3.1'] -> gdbm[version='>=1.18,<1.19.0a0']
# pillow -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# pyrsistent -> pypy3.6[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# lazy-object-proxy -> pypy3.7[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# brotlipy -> pypy3.7[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# cryptography -> pypy3.6[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# mock -> pypy3.6[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# ipykernel -> pypy3.6[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# mistune -> pypy3.7[version='>=7.3.4'] -> gdbm[version='>=1.18,<1.19.0a0']
# aiohttp -> pypy3.6[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# regex -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# llvmlite -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# ujson -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# protobuf -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# astropy -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# lxml -> pypy3.6[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# jupyter -> pypy3.7[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# jupyter_core -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# statsmodels -> pypy3.7[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# click -> pypy3.7[version='>=7.3.4'] -> gdbm[version='>=1.18,<1.19.0a0']
# nbconvert -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# bottleneck -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# terminado -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# bitarray -> pypy3.6[version='>=7.3.1'] -> gdbm[version='>=1.18,<1.19.0a0']
# wurlitzer -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# scipy -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# matplotlib-base -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# isort -> pypy3.6[version='>=7.3.2'] -> gdbm[version='>=1.18,<1.19.0a0']
# widgetsnbextension -> pypy3.7[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# docutils -> pypy3.7[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# conda-package-handling -> pypy3.7[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# promise -> pypy3.7[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# googleapis-common-protos -> pypy3.6[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# python_abi -> pypy3.7=7.3 -> gdbm[version='>=1.18,<1.19.0a0']
# tornado -> pypy3.6[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# pycurl -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# msgpack-python -> pypy3.6[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# pluggy -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# notebook -> pypy3.6[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# absl-py -> pypy3.6[version='>=7.3.2'] -> gdbm[version='>=1.18,<1.19.0a0']
# ninja -> pypy3.6[version='>=7.3.1'] -> gdbm[version='>=1.18,<1.19.0a0']
# pyyaml -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# backports.weakref -> pypy3.6[version='>=7.3.2'] -> gdbm[version='>=1.18,<1.19.0a0']
# scikit-learn -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# future -> pypy3.7[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# asn1crypto -> pypy3.6[version='>=7.3.1'] -> gdbm[version='>=1.18,<1.19.0a0']
# pywavelets -> pypy3.7[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# psutil -> pypy3.7[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# pandas -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# sympy -> pypy3.6[version='>=7.3.3'] -> gdbm[version='>=1.18,<1.19.0a0']
# soupsieve -> pypy3.6[version='>=7.3.1'] -> gdbm[version='>=1.18,<1.19.0a0']
# greenlet -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# bokeh -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# conda[version='>=4.10.3'] -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
# rtree -> pypy3.7[version='>=7.3.5'] -> gdbm[version='>=1.18,<1.19.0a0']
#
# Package readline conflicts for:
# dataclasses -> python[version='>=3.7'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*']
# pycparser -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# html5lib -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# idna -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# jupyterlab_pygments -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# qtconsole -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# openpyxl -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# mock -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# anaconda==2020.11 -> python==3.7.9=h7579374_0 -> readline[version='>=8.0,<9.0a0']
# spyder-kernels -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# cryptography -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# heapdict -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# pycodestyle -> python[version='2.7.*|>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# keyring -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# typing_extensions -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# sphinxcontrib-jsmath -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*']
# pytables -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# asn1crypto -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# google-auth -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pysocks -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# locket -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# h5py -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# nbconvert -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# sphinxcontrib-applehelp -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*']
# fastcache -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# olefile -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# nose -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# urllib3 -> python[version='<4.0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# setuptools -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# notebook -> python[version='>=3.7'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# dill -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# autopep8 -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# gmpy2 -> python[version='>=3.8,<3.9.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# rsa -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# pandas -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# sqlite -> readline[version='6.2.*|7.0|7.0.*|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0']
# toml -> python[version='>=2.7'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# ipython -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# conda-package-handling -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# webencodings -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# anaconda==2020.11 -> readline==8.0=h7b6447c_0
# argon2-cffi -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# mistune -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# jupyterlab -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# sphinxcontrib-htmlhelp -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*']
# singledispatch -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# opt_einsum -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# scikit-learn -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pygments -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# imagesize -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# packaging -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# atomicwrites -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# python=3.8 -> readline[version='>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0']
# sphinxcontrib-websupport -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# flake8 -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# transformers -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# send2trash -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# termcolor -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# wheel -> python[version='!=3.0,!=3.1,!=3.2,!=3.3,!=3.4'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# backports.functools_lru_cache -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# mpmath -> python[version='>=3'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pyyaml -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# scikit-image -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# docutils -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# zope -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# future -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# argh -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# googleapis-common-protos -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# anaconda-client -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pillow -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# threadpoolctl -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*']
# msgpack-python -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# sip -> python[version='>=3.8,<3.9.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# path.py -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# iniconfig -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# jupyter_client -> python[version='>=3.6.1'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pyjwt -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# dask-core -> python[version='>=3.7'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# ipython_genutils -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# cloudpickle -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# tensorflow-datasets -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# backports.shutil_get_terminal_size -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# glob2 -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# sortedcollections -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# backports.tempfile -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# lazy-object-proxy -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# bitarray -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# _ipyw_jlab_nb_ext_conf -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# llvmlite -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# astunparse -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# qdarkstyle -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# importlib-metadata -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# tifffile -> python[version='>=3.7'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# zope.event -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# gast -> python[version='>=3.4'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pep8 -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# zope.interface -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pyhocon -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# torchvision -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# boto -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# tensorboard -> python[version='>=3.2'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# beautifulsoup4 -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# prompt_toolkit -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# cachetools -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# py -> python[version='>=2.7'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# babel -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# pyopenssl -> python[version='>=2.7'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# qtawesome -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# path -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*']
# numexpr -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# jupyterlab_server -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*']
# google-pasta -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# alabaster -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# gevent -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# bokeh -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pyasn1-modules -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# kiwisolver -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# conda-build -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# sympy -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# unicodecsv -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# markdown -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# rtree -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pyodbc -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# matplotlib -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# sphinx -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# async-timeout -> python[version='>=3.5.3'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*']
# parso -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# navigator-updater -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# mkl_fft -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# bleach -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# conda-verify -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# wcwidth -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# pandocfilters -> python[version='!=3.0,!=3.1,!=3.2,!=3.3'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# cytoolz -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# asset -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# pydocstyle -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# sphinxcontrib-serializinghtml -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*']
# pathtools -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# cffi -> python[version='>=3.8,<3.9.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# nltk -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# wurlitzer -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pexpect -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# fsspec -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*']
# jupyter_core -> python[version='>=3.8,<3.9.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# intervaltree -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# zipp -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# toolz -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# six -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# ptyprocess -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# sphinxcontrib-qthelp -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*']
# tensorflow-base -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# terminado -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# lxml -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# blinker -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# jupyter -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# cycler -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# python-libarchive-c -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# defusedxml -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# multidict -> python[version='>=3.8,<3.9.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*']
# conda[version='>=4.10.3'] -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*']
# jsonschema -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pyrsistent -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# contextlib2 -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pylint -> python[version='>=3.6,<4'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# anaconda-project -> python[version='>=2.7'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# pycurl -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# jedi -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# widgetsnbextension -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# attrs -> python[version='>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*,!=3.4.*'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# joblib -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# xlrd -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# tensorflow-metadata -> python[version='>=3.6,<4.0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# colorama -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# ipywidgets -> python[version='>=3.3'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# keras-preprocessing -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# click -> python[version='>=3.8,<3.9.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pytest -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# grpcio -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# scipy -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pyqt -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# mccabe -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# importlib_metadata -> python[version='>=3.8,<3.9.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# seaborn -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# anaconda-navigator -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# statsmodels -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# numpydoc -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# matplotlib-base -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pytz -> python[version='>=3'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# ply -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# backcall -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# aadict -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# aiohttp -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*']
# mkl_random -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# google-auth-oauthlib -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# greenlet -> python[version='>=3.8,<3.9.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# werkzeug -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pyxdg -> python[version='>=3'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# isort -> python[version='>=3.6,<4.0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# qtpy -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# tensorflow -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# spyder -> python[version='>=3.8,<3.9.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# markupsafe -> python[version='>=3.8,<3.9.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# multipledispatch -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# tblib -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# astroid -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# ipykernel -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# numpy-base -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# distributed -> python[version='>=3.8,<3.9.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# python-language-server -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pip -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# more-itertools -> python[version='>=3.4'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# chardet -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pyasn1 -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# pytorch -> python[version='>=3.8,<3.9.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# filelock -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# nbformat -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# jdcal -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# jeepney -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*']
# python-jsonrpc-server -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# mkl-service -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# flask -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# ruamel_yaml -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# nbclient -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*']
# yarl -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*']
# globre -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# patsy -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# prompt-toolkit -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*']
# pathlib2 -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pycosat -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# sphinxcontrib-devhelp -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*']
# watchdog -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# requests-oauthlib -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# regex -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# backports -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# tqdm -> python[version='>=2.7'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# networkx -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# traitlets -> python[version='>=3.7'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# zict -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# rope -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# soupsieve -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# requests -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# tornado -> python[version='>=3.8,<3.9.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# qt -> libpq[version='>=13.1,<14.0a0'] -> readline[version='7.0|7.0.*|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0']
# partd -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# psutil -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# clyent -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# numpy -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# bkcharts -> python=3.6 -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# python-dateutil -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# prometheus_client -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# tensorflow-estimator -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# absl-py -> python[version='>=3'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# diff-match-patch -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# py-lief -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pkginfo -> python[version='>=3'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# wrapt -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# glib -> python= -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# json5 -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# simplegeneric -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# brotlipy -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# jupyter_console -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# yapf -> python[version='>=2.7'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# pyparsing -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# python_abi -> python=3.9 -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# promise -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# entrypoints -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# et_xmlfile -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# xlsxwriter -> python[version='>=3.4'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# bottleneck -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# tensorboard-plugin-wit -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# xlwt -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# numba -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pyflakes -> python[version='2.7.*|>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# oauthlib -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# sortedcontainers -> python[version='>=2.7'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# async_generator -> python[version='>2.7'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# itsdangerous -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# jsonlines -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# conda-env -> python=3.5 -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|7.*|7.0.*']
# pickleshare -> python[version='>=3'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# secretstorage -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# cython -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# dask -> python[version='>=3.7'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# certifi -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# astropy -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# backports.weakref -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# jinja2 -> python[version='>=3.6'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# decorator -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# sphinxcontrib -> python[version='>=3.9,<3.10.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# sacremoses -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# nest-asyncio -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*']
# pyzmq -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# xmltodict -> python -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.0.*|7.*']
# testpath -> python[version='>=3.5'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pluggy -> python[version='>=3.6,<3.7.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# pywavelets -> python[version='>=3.7,<3.8.0a0'] -> readline[version='6.2.*|7.0|>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0|7.*|7.0.*']
# ...
# pytest -> wcwidth
# astropy -> pytest -> wcwidth
# jupyter_console -> prompt_toolkit[version='>=2.0.0,<3.1.0,!=3.0.0,!=3.0.1'] -> wcwidth
# prompt-toolkit -> wcwidth
# anaconda==2020.11 -> wcwidth==0.2.5=py_0
# anaconda==2020.11 -> prompt-toolkit==3.0.8=py_0 -> wcwidth
# nltk -> pytest -> wcwidth
#
# Package selectors2 conflicts for:
# wurlitzer -> selectors2
# spyder-kernels -> wurlitzer[version='>=1.0.3'] -> selectors2
#
# Package libnghttp2 conflicts for:
# curl -> libcurl==7.79.0=h2574ce0_0 -> libnghttp2[version='>=1.41.0,<2.0a0|>=1.43.0,<2.0a0']
# pycurl -> libcurl[version='>=7.78.0,<8.0a0'] -> libnghttp2[version='>=1.41.0,<2.0a0|>=1.43.0,<2.0a0']
# tensorflow -> libcurl[version='>=7.71.1,<8.0a0'] -> libnghttp2[version='>=1.41.0,<2.0a0|>=1.43.0,<2.0a0']
# tensorflow-base -> libcurl[version='>=7.78.0,<8.0a0'] -> libnghttp2[version='>=1.41.0,<2.0a0|>=1.43.0,<2.0a0']
# libcurl -> libnghttp2[version='>=1.41.0,<2.0a0|>=1.43.0,<2.0a0']
# hdf5 -> libcurl[version='>=7.77.0,<8.0a0'] -> libnghttp2[version='>=1.41.0,<2.0a0|>=1.43.0,<2.0a0']
#
# Package qtawesome conflicts for:
# anaconda==2020.11 -> qtawesome==1.0.1=py_0
# spyder -> qtawesome[version='>=0.4.1|>=0.5.7|>=1.0.2']
# anaconda==2020.11 -> spyder==4.1.5=py37_0 -> qtawesome[version='>=0.5.7']
#
# Package googleapis-common-protos conflicts for:
# tensorflow-metadata -> googleapis-common-protos[version='>=1.52.0,<2']
# tensorflow-datasets -> tensorflow-metadata -> googleapis-common-protos[version='>=1.52.0,<2']
#
# Package scikit-learn conflicts for:
# anaconda==2020.11 -> scikit-learn==0.23.2[build='py37h0573a6f_0|py38h0573a6f_0']
# nltk -> scikit-learn
#
# Package mpmath conflicts for:
# sympy -> mpmath[version='>=0.19']
# anaconda==2020.11 -> sympy==1.6.2=py37h06a4308_1 -> mpmath[version='>=0.19']
# anaconda==2020.11 -> mpmath==1.1.0[build='py38_0|py37_0']
#
# Package twisted conflicts for:
# prometheus_client -> twisted
# notebook -> prometheus_client -> twisted
#
# Package networkx conflicts for:
# scikit-image -> networkx[version='>=1.8,<2.0|>=1.8|>=2.0']
# anaconda==2020.11 -> scikit-image==0.17.2=py37hdf5156a_0 -> networkx[version='>=2.0']
# anaconda==2020.11 -> networkx==2.5=py_0
#
# Package gnutls conflicts for:
# ffmpeg -> gnutls[version='3.5.*|>=3.5.19,<3.6.0a0|>=3.6.13,<3.7.0a0|>=3.6.5,<3.7.0a0']
# torchvision -> ffmpeg[version='>=4.2'] -> gnutls[version='>=3.6.13,<3.7.0a0|>=3.6.5,<3.7.0a0']
#
# Package py-lief conflicts for:
# anaconda==2020.11 -> py-lief==0.10.1[build='py38h403a769_0|py37h403a769_0']
# conda-build -> py-lief
#
# Package brotlipy conflicts for:
# anaconda==2020.11 -> brotlipy==0.7.0[build='py38h7b6447c_1000|py37h7b6447c_1000']
# anaconda==2020.11 -> urllib3==1.25.11=py_0 -> brotlipy[version='>=0.6.0']
# urllib3 -> brotlipy[version='>=0.6.0']
# requests -> urllib3[version='>=1.21.1,<1.27'] -> brotlipy[version='>=0.6.0']
#
# Package libllvm9 conflicts for:
# llvmlite -> libllvm9[version='9.0.1|>=9.0.1,<9.1.0a0',build=*_1]
# llvmlite -> llvmdev=9.0 -> libllvm9[version='9.0.1|9.0.1|>=9.0.0,<9.0.1a0|>=9.0.1,<9.0.2a0',build='h4a3c616_1|h4a3c616_0']
#
# Package pkginfo conflicts for:
# conda-build -> pkginfo
# anaconda==2020.11 -> pkginfo==1.6.1[build='py37h06a4308_0|py38h06a4308_0']
#
# Package mpi conflicts for:
# hdf5 -> mpich[version='>=3.4,<4.0.0a0'] -> mpi==1.0[build='mpich|openmpi']
# h5py -> mpich[version='>=3.4.2,<4.0a0'] -> mpi==1.0[build='mpich|openmpi']
#
# Package multidict conflicts for:
# google-auth -> aiohttp[version='>=3.6.2,<4.0.0dev'] -> multidict[version='>=2.1.4|>=4.0,<5.0|>=4.5,<5.0|>=4.5,<7.0|>=3.0.0']
# yarl -> multidict[version='>=2.0|>=4.0']
# aiohttp -> yarl[version='>=1.0,<2.0'] -> multidict[version='>=2.0|>=4.0']
# aiohttp -> multidict[version='>=2.1.4|>=4.0,<5.0|>=4.5,<5.0|>=4.5,<7.0|>=3.0.0']
#
# Package openh264 conflicts for:
# torchvision -> ffmpeg[version='>=4.2'] -> openh264[version='>=1.8.0,<1.9.0a0|>=2.1.1,<2.2.0a0|>=2.1.0,<2.2.0a0']
# ffmpeg -> openh264[version='1.7.*|>=1.8.0,<1.9.0a0|>=2.1.1,<2.2.0a0|>=2.1.0,<2.2.0a0']
#
# Package poyo conflicts for:
# transformers -> cookiecutter==1.7.2 -> poyo[version='>=0.5.0']
# spyder -> cookiecutter[version='>=1.6.0'] -> poyo[version='>=0.1.0|>=0.5.0']
#
# Package openmpi conflicts for:
# h5py -> hdf5[version='>=1.12.1,<1.12.2.0a0'] -> openmpi[version='3.0.*|>=4.0,<5.0.0a0|>=4.1,<4.2.0a0|>=4.0,<4.1.0a0']
# h5py -> openmpi[version='>=3.1,<3.2.0a0|>=3.1.4,<3.2.0a0|>=4.0.1,<5.0.0a0|>=4.0.2,<5.0.0a0|>=4.0.4,<5.0.0a0|>=4.0.5,<5.0.0a0|>=4.1.0,<5.0a0|>=4.1.1,<5.0a0']
#
# Package libvorbis conflicts for:
# gst-plugins-base -> libvorbis[version='>=1.3.7,<1.4.0a0']
# qt -> gst-plugins-base[version='>=1.18.3,<1.19.0a0'] -> libvorbis[version='>=1.3.7,<1.4.0a0']
#
# Package black conflicts for:
# attrs -> hypothesis -> black[version='>=19.10b0']
# spyder -> python-lsp-black[version='>=1.0.0'] -> black
#
# Package libidn2 conflicts for:
# ffmpeg -> gnutls[version='>=3.6.13,<3.7.0a0'] -> libidn2[version='>=2,<3.0a0']
# gnutls -> libidn2[version='>=2,<3.0a0']The following specifications were found to be incompatible with your system:
#
#   - feature:/linux-64::__glibc==2.28=0
#   - feature:|@/linux-64::__glibc==2.28=0
#   - aiohttp -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - argon2-cffi -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - astropy -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - bitarray -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - blas -> libgfortran-ng -> __glibc[version='>=2.17']
#   - blosc -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - bottleneck -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - brotlipy -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - bzip2 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - c-ares -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cairo -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cffi -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - conda-package-handling -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cryptography -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cudatoolkit -> __glibc[version='>=2.17,<3.0.a0']
#   - cudatoolkit -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cudnn -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - curl -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cython -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cytoolz -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - dbus -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - expat -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - fastcache -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - ffmpeg -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - fontconfig -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - freetype -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - fribidi -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - gevent -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - glib -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - gmp -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - gmpy2 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - gnutls -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - graphite2 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - greenlet -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - grpcio -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - gst-plugins-base -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - gstreamer -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - h5py -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - harfbuzz -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - hdf5 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - icu -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - jbig -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - jpeg -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - kiwisolver -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - krb5 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - lame -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - lazy-object-proxy -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - lcms2 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libarchive -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libcurl -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libedit -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libffi -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libgcc-ng -> __glibc[version='>=2.17']
#   - libgfortran-ng -> __glibc[version='>=2.17']
#   - libiconv -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libidn2 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - liblief -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libllvm10 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libpng -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libprotobuf -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libsodium -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libspatialindex -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libssh2 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libstdcxx-ng -> __glibc[version='>=2.17']
#   - libtasn1 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libtiff -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libtool -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libunistring -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libuuid -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libuv -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libxcb -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libxml2 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libxslt -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - llvmlite -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - lxml -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - lz4-c -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - lzo -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - markupsafe -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - matplotlib -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - matplotlib-base -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - mecab -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - mistune -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - mkl-service -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - mkl_fft -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - mkl_random -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - mpc -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - mpfr -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - msgpack-python -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - multidict -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - ncurses -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - nettle -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - ninja -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - numba -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - numexpr -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - numpy -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - numpy-base -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - openh264 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - openssl -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pandas -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pango -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - patchelf -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - pcre -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pillow -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pixman -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - protobuf -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - psutil -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - py-lief -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pycosat -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pycurl -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pyodbc -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pyqt -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - pyrsistent -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pytables -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - python=3.8 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pytorch -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - pywavelets -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pyyaml -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pyzmq -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - qt -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - readline -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - regex -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - ripgrep -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - ruamel_yaml -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - scikit-image -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - scikit-learn -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - scipy -> libgfortran-ng -> __glibc[version='>=2.17']
#   - sip -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - sqlalchemy -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - sqlite -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - statsmodels -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - tbb -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - tensorboard -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - tensorflow -> libgcc-ng[version='>=5.4.0'] -> __glibc[version='>=2.17']
#   - tensorflow-base -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - tensorflow-metadata -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - tifffile -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - tk -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - tokenizers -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - torchvision -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - tornado -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - transformers -> pytorch -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - ujson -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - unixodbc -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - wrapt -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - xz -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - yaml -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - yarl -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - zeromq -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - zlib -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - zope.interface -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - zstd -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#
# Your installed version is: 2.28
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge mecab-python3
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: |
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                                                                      |failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - alabaster -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|3.4.*|>=3.7,<3.8.0a0']
#   - anaconda==2020.11 -> python[version='3.7.9|3.8.5',build='h7579374_1|h7579374_0']
#   - argon2-cffi -> python[version='2.7.*|3.5.*|3.6.*|3.6.12|3.6.12|3.7.10|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|>=3.5,<3.6.0a0|3.4.*|3.7.*|3.9.*|3.8.*',build='0_73_pypy|1_73_pypy|2_73_pypy|4_73_pypy|5_73_pypy|5_73_pypy|1_73_pypy|0_73_pypy|3_73_pypy']
#   - atomicwrites -> python[version='2.7.*|3.5.*|3.6.*|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - backports -> python[version='2.7.*|3.5.*|3.6.*|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0']
#   - bkcharts -> python[version='3.4.*|>=3.7.1,<3.8.0a0']
#   - brotlipy -> python[version='3.4.*|3.6.12|3.6.12|3.7.10|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|3.9.*|3.8.*|3.7.*',build='0_73_pypy|1_73_pypy|2_73_pypy|4_73_pypy|5_73_pypy|5_73_pypy|1_73_pypy|0_73_pypy|3_73_pypy']
#   - cffi -> python[version='2.7.*|3.5.*|3.6.*|3.6.12|3.6.12|3.7.10|3.7.10|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.9,<3.10.0a0|3.7.9|3.6.9|3.6.9|3.6.9|>=2.7,<2.8.0a0|3.6.9|>=3.5,<3.6.0a0|3.4.*',build='0_73_pypy|1_73_pypy|2_73_pypy|4_73_pypy|5_73_pypy|5_73_pypy|1_73_pypy|0_73_pypy|3_73_pypy']
#   - colorama -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - conda-env -> python[version='2.7.*|3.4.*|3.5.*']
#   - cryptography -> python[version='3.4.*|3.6.12|3.6.12|3.7.10|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|3.9.*|3.7.*|3.8.*|>=3.5|<=3.3',build='0_73_pypy|1_73_pypy|2_73_pypy|4_73_pypy|5_73_pypy|5_73_pypy|1_73_pypy|0_73_pypy|3_73_pypy']
#   - diff-match-patch -> python[version='2.7.*|3.4.*|3.5.*|3.6.*']
#   - filelock -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - gevent -> python[version='3.4.*|3.6.12|3.6.12|3.7.10|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|3.7.*|3.9.*|3.8.*',build='0_73_pypy|1_73_pypy|2_73_pypy|4_73_pypy|5_73_pypy|5_73_pypy|1_73_pypy|0_73_pypy|3_73_pypy']
#   - glob2 -> python[version='2.7.*|3.4.*|3.5.*|3.6.*|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - html5lib -> python[version='2.7.*|3.5.*|3.6.*|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0']
#   - imageio -> python[version='>=3.9,<3.10.0a0']
#   - imagesize -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0']
#   - intervaltree -> python[version='2.7.*|3.5.*|3.6.*']
#   - jdcal -> python[version='2.7.*|3.5.*|3.6.*|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - jsonlines -> python[version='2.7.*|3.5.*|3.6.*']
#   - more-itertools -> python[version='3.4.*|>=3.9,<3.10.0a0']
#   - olefile -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0']
#   - pathtools -> python[version='2.7.*|3.4.*|3.5.*|3.6.*']
#   - pyasn1 -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0']
#   - pycodestyle -> python[version='>=3.9,<3.10.0a0']
#   - pyflakes -> python[version='>=3.9,<3.10.0a0']
#   - pyopenssl -> python[version='>=3.9,<3.10.0a0']
#   - pyparsing -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - pytorch -> python[version='2.7.*|3.5.*|3.6.*|3.6.12|3.6.12|3.7.10|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|3.4.*|3.8.*|>=3.5|3.9.*|3.7.*|>=3.7|>=3.6,<3.7|>=3',build='0_73_pypy|1_73_pypy|2_73_pypy|4_73_pypy|5_73_pypy|5_73_pypy|1_73_pypy|0_73_pypy|3_73_pypy']
#   - requests-oauthlib -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|3.4.*|>=3.7,<3.8.0a0']
#   - rsa -> python[version='2.7.*|3.4.*|3.5.*|3.6.*']
#   - rsa -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - singledispatch -> python[version='>=3.9,<3.10.0a0']
#   - sphinxcontrib-websupport -> python[version='2.7.*|3.5.*|3.6.*|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0']
#   - tifffile -> python[version='>=3.9,<3.10.0a0']
#   - xmltodict -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0']
#   - zict -> python[version='2.7.*|3.5.*|3.6.*|3.4.*|>=3.6,<3.7.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - zope.event -> python[version='2.7.*|3.5.*|3.6.*|>=3.5,<3.6.0a0|3.4.*']
#
# Your python: python=3.8
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package six conflicts for:
# prompt_toolkit -> six[version='>=1.9.0']
# packaging -> six
# matplotlib-base -> cycler[version='>=0.10'] -> six[version='>=1.5']
# ipython -> prompt-toolkit[version='>=2.0.0,!=3.0.0,!=3.0.1,<3.1.0'] -> six[version='>=1.9.0']
# anaconda==2020.11 -> argon2-cffi==20.1.0=py37h7b6447c_1 -> six[version='>=1.11.0|>=1.12,<2|>=1.5.2|>=1.4.1|>=1.9|>=1.5']
# absl-py -> six
# mkl-service -> six
# numpy -> mkl-service[version='>=2.3.0,<3.0a0'] -> six
# python-dateutil -> six[version='>=1.5']
# seaborn -> patsy -> six
# protobuf -> six
# pytables -> six
# asset -> six[version='>=1.10.0']
# pytest -> six[version='>=1.10.0']
# mock -> six
# google-auth -> pyopenssl[version='>=20.0.0'] -> six[version='>=1.5.2']
# qtawesome -> six
# pyopenssl -> six[version='>=1.5.2']
# pyhocon -> asset -> six[version='>=1.10.0']
# grpcio -> six[version='>=1.5.2']
# prompt-toolkit -> six[version='>=1.9.0']
# nltk -> six
# anaconda-client -> python-dateutil[version='>=2.6.1'] -> six[version='>=1.5']
# tensorflow-metadata -> absl-py[version='>=0.9,<0.13'] -> six[version='>=1.10.0']
# ipykernel -> traitlets[version='>=4.1.0,<6.0'] -> six
# tensorflow -> six[version='>=1.10.0']
# mkl_fft -> mkl-service[version='>=2,<3.0a0'] -> six
# spyder -> cookiecutter[version='>=1.6.0'] -> six[version='>=1.10|>=1.11.0|>=1.5']
# traitlets -> six
# patsy -> six
# tensorboard -> google-auth[version='>=1.6.3,<2'] -> six[version='>=1.5.2|>=1.9.0|>=1.9.0,<2dev|>=1.9']
# torchvision -> six
# astunparse -> six[version='>=1.6.1,<2.0']
# tensorflow-estimator -> absl-py[version='>=0.7.0'] -> six[version='1.15.0.*|>=1.5.2|>=1.15.0|>=1.12.0|>=1.12.0,<2.0a0']
# argon2-cffi -> six
# ipywidgets -> traitlets[version='>=4.3.1,<6.0.0'] -> six
# numpydoc -> sphinx -> six[version='>=1.5']
# matplotlib -> cycler -> six[version='>=1.5']
# sphinx -> six[version='>=1.5']
# dask -> bokeh[version='>=1.0.0,!=2.0.0'] -> six[version='>=1.5.2']
# cryptography -> six[version='>=1.4.1']
# python-language-server -> pydocstyle[version='>=2.0.0'] -> six
# jupyterlab -> packaging -> six
# keras-preprocessing -> six[version='>=1.9.0']
# anaconda-client -> six
# notebook -> argon2-cffi -> six
# anaconda-project -> anaconda-client -> six
# singledispatch -> six
# pyjwt -> cryptography[version='>=1.4'] -> six[version='>=1.4.1']
# html5lib -> six[version='>=1.9']
# pyrsistent -> six
# wheel -> packaging[version='>=20.2'] -> six
# anaconda==2020.11 -> six==1.15.0[build='py37h06a4308_0|py38h06a4308_0']
# jupyter_core -> traitlets -> six
# oauthlib -> cryptography -> six[version='>=1.4.1']
# nltk -> pytest -> six[version='>=1.10.0|>=1.5.0']
# aadict -> six[version='>=1.6.0']
# conda-build -> six
# jsonschema -> pyrsistent[version='>=0.14.0'] -> six
# pyopenssl -> cryptography[version='>=3.2'] -> six[version='>=1.4.1']
# pytorch -> mkl-service[version='>=2,<3.0a0'] -> six
# scikit-image -> six[version='>=1.4|>=1.7.3']
# tensorflow-base -> six[version='1.15.0.*|>=1.15.0|>=1.10.0|>=1.12.0|>=1.12.0,<2.0a0']
# dask-core -> packaging[version='>=20.0'] -> six
# widgetsnbextension -> traitlets[version='>=4.3.1'] -> six
# tensorflow-estimator -> six[version='>=1.10.0']
# nbclient -> traitlets[version='>=4.2'] -> six
# grpcio -> protobuf[version='>=3.5.0'] -> six
# jsonlines -> six
# conda-verify -> six
# promise -> six
# bokeh -> six[version='>=1.5.2']
# tornado -> singledispatch -> six
# pydocstyle -> six
# sacremoses -> six
# bokeh -> packaging[version='>=16.8'] -> six[version='>=1.5']
# jupyter_console -> prompt_toolkit[version='>=2.0.0,<3.1.0,!=3.0.0,!=3.0.1'] -> six[version='>=1.9.0']
# cycler -> six
# jupyterlab_server -> jsonschema[version='>=3.0.1'] -> six[version='>=1.11.0']
# jupyter_client -> python-dateutil[version='>=2.1'] -> six[version='>=1.5']
# conda-package-handling -> six
# pathlib2 -> six
# importlib_metadata -> pathlib2 -> six
# pickleshare -> pathlib2 -> six
# h5py -> unittest2 -> six[version='>=1.4']
# h5py -> six
# pylint -> astroid==2.5.6 -> six[version='>=1.12,<2']
# tensorflow-base -> absl-py[version='>=0.10.0'] -> six[version='>=1.5.2|>=1.6.1,<2.0|>=1.9.0']
# statsmodels -> patsy[version='>=0.5.1'] -> six
# pytest -> more-itertools[version='>=4.0.0'] -> six[version='>=1.0.0,<2.0.0']
# tensorboard -> six[version='>=1.10.0|>=1.12']
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> six[version='>=1.11.0']
# pylint -> six
# testpath -> pathlib2 -> six
# importlib-metadata -> pathlib2 -> six
# numexpr -> mkl-service[version='>=2.3.0,<3.0a0'] -> six
# qtconsole -> traitlets -> six
# numba -> singledispatch -> six
# pandas -> python-dateutil[version='>=2.7.3'] -> six[version='>=1.5']
# asset -> aadict[version='>=0.2.2'] -> six[version='>=1.6.0']
# tensorflow-gpu -> tensorflow==1.13.1 -> six[version='>=1.10.0']
# googleapis-common-protos -> protobuf[version='>=3.12.0'] -> six
# conda[version='>=4.10.3'] -> conda-package-handling[version='>=1.3.0'] -> six[version='>=1.5.2']
# scipy -> mkl-service[version='>=2.3.0,<3.0a0'] -> six
# google-pasta -> six
# bkcharts -> six[version='>=1.5.2']
# scikit-learn -> mkl-service[version='>=2,<3.0a0'] -> six
# transformers -> packaging -> six[version='>=1.10|>=1.10.0']
# multipledispatch -> six
# distributed -> bokeh[version='>=0.12.3'] -> six[version='>=1.5.2']
# anaconda-navigator -> anaconda-client[version='>=1.6.14'] -> six
# nbconvert -> bleach -> six[version='>=1.9.0']
# urllib3 -> cryptography[version='>=1.3.4'] -> six[version='>=1.4.1|>=1.5.2']
# google-auth-oauthlib -> google-auth[version='>=1.0.0'] -> six[version='>=1.4.1|>=1.9.0|>=1.9.0,<2dev']
# more-itertools -> six[version='>=1.0.0,<2.0.0']
# google-auth -> six[version='>=1.9.0|>=1.9.0,<2dev']
# mkl_random -> mkl-service[version='>=2,<3.0a0'] -> six
# tensorflow-datasets -> six=1.15
# zipp -> more-itertools -> six[version='>=1.0.0,<2.0.0']
# secretstorage -> cryptography -> six[version='>=1.4.1']
# jsonschema -> six[version='>=1.11.0']
# distributed -> six
# astroid -> six[version='>=1.12,<2']
# numpy-base -> mkl-service[version='>=2.3.0,<3.0a0'] -> six
# astropy -> pytest[version='<4'] -> six[version='>=1.10.0']
# tensorflow -> tensorflow-base==2.4.3=py39h23a8cbf_0 -> six[version='1.15.0.*|>=1.15.0|>=1.5.2|>=1.9.0|>=1.9|>=1.12|>=1.12.0|>=1.12.0,<2.0a0']
#
# Package importlib_metadata conflicts for:
# transformers -> huggingface_hub -> importlib_metadata
# jupyterlab_server -> jsonschema[version='>=3.0.1'] -> importlib_metadata
# python-language-server -> pluggy -> importlib_metadata[version='>=0.12|>=0.9']
# keyring -> importlib_metadata[version='>=1|>=3.6']
# spyder -> jsonschema[version='>=3.2.0'] -> importlib_metadata[version='>=1|>=3.6']
# tensorflow-datasets -> importlib_resources -> importlib_metadata
# ipykernel -> argcomplete[version='>=1.12.3'] -> importlib_metadata[version='>=0.23,<4|>=0.23,<5']
# pluggy -> importlib_metadata[version='>=0.12|>=0.9']
# jsonschema -> importlib_metadata
# path.py -> importlib_metadata[version='>=0.5']
# sqlalchemy -> importlib_metadata
# nltk -> pytest -> importlib_metadata[version='>=0.12']
# pytest -> importlib_metadata[version='>=0.12']
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> importlib_metadata
# path -> importlib_metadata[version='>=0.5']
# astropy -> pytest -> importlib_metadata[version='>=0.12']
# pytest -> pluggy[version='>=0.9'] -> importlib_metadata[version='>=0.9']
# anaconda==2020.11 -> importlib_metadata==2.0.0=1
# anaconda==2020.11 -> jsonschema==3.2.0=py_2 -> importlib_metadata[version='>=0.12|>=0.5']
#
# Package nbconvert conflicts for:
# jupyter -> nbconvert
# jupyterlab_server -> jupyter_server[version='>=1.4,<2'] -> nbconvert[version='<6.0']
# anaconda==2020.11 -> jupyter==1.0.0=py37_7 -> nbconvert[version='>=4.0']
# ipywidgets -> notebook -> nbconvert[version='<6.0']
# jupyter -> notebook -> nbconvert[version='<6.0']
# spyder -> nbconvert[version='>=4.0']
# widgetsnbextension -> notebook[version='>=4.4.1'] -> nbconvert[version='<6.0']
# anaconda==2020.11 -> nbconvert==6.0.7[build='py37_0|py38_0']
# notebook -> nbconvert[version='<6.0']
# jupyterlab -> jupyter_server[version='>=1.4,<2'] -> nbconvert[version='<6.0']
#
# Package libstdcxx-ng conflicts for:
# nettle -> gmp[version='>=6.1.2,<7.0a0'] -> libstdcxx-ng[version='>=7.2.0|>=7.5.0']
# keras-preprocessing -> numpy[version='>=1.9.1'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=9.3.0|>=7.5.0|>=9.4.0|>=7.2.0']
# mkl -> tbb=2021 -> libstdcxx-ng[version='>=7.3.0|>=7.5.0|>=9.3.0']
# fastcache -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# terminado -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# zstd -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0']
# anaconda==2020.11 -> blosc==1.20.1=hd408876_0 -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# ncurses -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=7.2.0']
# nbformat -> python[version='>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# sqlite -> libstdcxx-ng[version='>=4.9|>=7.3.0']
# astunparse -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pkginfo -> python[version='>=3'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# krb5 -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=7.2.0']
# tensorboard-plugin-wit -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# idna -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pandas -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# python=3.8 -> libstdcxx-ng[version='>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0']
# networkx -> matplotlib-base[version='>=3.3'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pyodbc -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pyzmq -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=7.2.0']
# sphinxcontrib-serializinghtml -> python[version='>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# gevent -> greenlet[version='>=1.1.0,<2.0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# xlrd -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pycparser -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# dataclasses -> python[version='>=3.7'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# more-itertools -> python[version='>=3.4'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# numpy-base -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# liblief -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=7.5.0|>=9.3.0']
# sympy -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# conda-build -> patchelf -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.4.0|>=7.2.0|>=9.3.0']
# markupsafe -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# mkl_fft -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# numba -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# jupyterlab -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# argh -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# et_xmlfile -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# nbclient -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# babel -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# libtiff -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=7.2.0']
# mecab-python3 -> libstdcxx-ng[version='>=9.3.0']
# entrypoints -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# lcms2 -> libtiff[version='>=4.2.0,<5.0a0'] -> libstdcxx-ng[version='>=7.3.0|>=9.3.0|>=7.5.0']
# wurlitzer -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# keyring -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# graphite2 -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=7.2.0']
# certifi -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# opt_einsum -> numpy -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=9.3.0|>=7.5.0|>=9.4.0|>=7.2.0']
# tensorflow-metadata -> libstdcxx-ng[version='>=7.3.0']
# curl -> krb5[version='>=1.19.2,<1.20.0a0'] -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=7.5.0|>=9.3.0']
# jupyter_core -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# libffi -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.4.0|>=7.2.0']
# conda[version='>=4.10.3'] -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pillow -> libtiff[version='>=4.3.0,<5.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# importlib-metadata -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# qdarkstyle -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# ninja -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='>=9.4.0']
# attrs -> python[version='>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*,!=3.4.*'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pickleshare -> python[version='>=3'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# mpfr -> gmp[version='>=6.2.1,<7.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=7.2.0']
# py-lief -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=7.5.0|>=9.3.0']
# tqdm -> python[version='>=2.7'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pyyaml -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# notebook -> python[version='>=3.7'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# backports.weakref -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# unicodecsv -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# tornado -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# libxslt -> icu[version='>=68.1,<69.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=7.2.0']
# mkl_random -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=9.4.0']
# multipledispatch -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# scikit-image -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# nose -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# spyder-kernels -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# patsy -> numpy[version='>=1.4.0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=9.3.0|>=7.5.0|>=9.4.0|>=7.2.0']
# simplegeneric -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# tensorflow-base -> grpc-cpp[version='>=1.37.1,<1.38.0a0'] -> libstdcxx-ng[version='>=3.4|>=4.9|>=7.3.0|>=7.5.0']
# cairo -> icu[version='>=68.1,<69.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.5.0|>=9.4.0|>=9.3.0']
# pyjwt -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# itsdangerous -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pep8 -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pathlib2 -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# lxml -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# _ipyw_jlab_nb_ext_conf -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pip -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# cython -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='>=9.4.0']
# cudnn -> libstdcxx-ng[version='>=3.4']
# urllib3 -> python[version='<4.0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# sortedcontainers -> python[version='>=2.7'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# markdown -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# bokeh -> numpy[version='>=1.11.3'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=9.4.0|>=9.3.0|>=7.5.0|>=7.2.0']
# zope.event -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# wcwidth -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# secretstorage -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# msgpack-python -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=9.4.0']
# async_generator -> python[version='>2.7'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# jinja2 -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# xlsxwriter -> python[version='>=3.4'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# google-auth-oauthlib -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# yarl -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# blinker -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# protobuf -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# mock -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# prompt_toolkit -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# scikit-learn -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# six -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# statsmodels -> pandas[version='>=0.23'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# openpyxl -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pyparsing -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# anaconda-project -> python[version='>=2.7'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# msgpack-python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=7.2.0']
# widgetsnbextension -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# asset -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# qt -> gst-plugins-base[version='>=1.18.3,<1.19.0a0'] -> libstdcxx-ng[version='>=4.9|>=9.4.0']
# numpy -> libstdcxx-ng[version='>=4.9|>=7.3.0']
# nbconvert -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# gmpy2 -> gmp[version='>=6.2.1,<7.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.4.0|>=9.3.0|>=7.2.0']
# matplotlib -> matplotlib-base[version='>=3.4.3,<3.4.4.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.5.0|>=9.4.0|>=9.3.0']
# ffmpeg -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=7.2.0']
# astroid -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# beautifulsoup4 -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pyhocon -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# dbus -> expat[version='>=2.3.0,<3.0.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=9.3.0|>=9.4.0|>=7.5.0|>=7.2.0']
# atomicwrites -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# typing_extensions -> python[version='>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# libprotobuf -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# qtawesome -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# numpy -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.2.0|>=7.5.0|>=9.3.0|>=9.4.0']
# libedit -> ncurses[version='>=6.2,<6.3.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=7.2.0']
# testpath -> python[version='>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pysocks -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# chardet -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pexpect -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# backports.shutil_get_terminal_size -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# jeepney -> python[version='>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# blosc -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=7.2.0']
# pandoc -> gmp -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=7.2.0']
# libllvm10 -> libstdcxx-ng[version='>=7.3.0|>=7.5.0|>=9.3.0']
# sphinxcontrib-qthelp -> python[version='>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# cloudpickle -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# ipywidgets -> python[version='>=3.3'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# json5 -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# libspatialindex -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# tensorflow-estimator -> protobuf[version='>=3.6.1'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0|>=5.4.0']
# imagesize -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# click -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# sacremoses -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# libidn2 -> gettext[version='>=0.19.8.1,<1.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# python-libarchive-c -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pcre -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=9.3.0|>=7.5.0|>=7.2.0']
# ptyprocess -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# greenlet -> libstdcxx-ng[version='>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0']
# torchvision -> libstdcxx-ng[version='>=5.4.0|>=7.3.0|>=7.5.0']
# jupyter -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# tensorflow-metadata -> protobuf[version='>=3.7,<4'] -> libstdcxx-ng[version='>=4.9|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0|>=5.4.0']
# toml -> python[version='>=2.7'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# diff-match-patch -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# sphinxcontrib-devhelp -> python[version='>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# backports.functools_lru_cache -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# anaconda==2020.11 -> libstdcxx-ng==9.1.0=hdf63c60_0
# ujson -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.2.0']
# partd -> python[version='>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pytest -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# mccabe -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# torchvision -> cudatoolkit[version='11.1|11.1.*'] -> libstdcxx-ng[version='>=3.4|>=9.3.0|>=9.4.0|>=4.9|>=7.2.0']
# pydocstyle -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# jsonschema -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# gstreamer -> gettext[version='>=0.19.8.1,<1.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=9.4.0|>=9.3.0|>=7.5.0|>=7.2.0']
# pycosat -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# spyder -> pyqt[version='>=5.6,<5.13'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=7.2.0|>=9.4.0|>=9.3.0']
# nest-asyncio -> python[version='>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# gst-plugins-base -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# nltk -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# tifffile -> imagecodecs[version='>=2021.7.30'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=9.3.0|>=7.5.0|>=9.4.0|>=7.2.0']
# cycler -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# google-auth -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# ruamel_yaml -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# glob2 -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# qtconsole -> pyqt -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=7.2.0|>=9.3.0|>=9.4.0']
# pycurl -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# jdcal -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# numexpr -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# rsa -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# globre -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# soupsieve -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pyqt -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=7.2.0']
# mpc -> gmp[version='>=6.2.1,<7.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=7.2.0']
# pyqt -> pyqt-impl==5.12.3=py39h0fcd23e_7 -> libstdcxx-ng[version='>=9.3.0|>=9.4.0']
# jupyter_client -> python[version='>=3.6.1'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# cachetools -> python[version='>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# libarchive -> lz4-c[version='>=1.9.3,<1.9.4.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=7.2.0']
# pluggy -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# unixodbc -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0']
# absl-py -> python[version='>=3'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pylint -> python[version='>=3.6,<4'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# conda-env -> python=3.5 -> libstdcxx-ng[version='>=4.9|>=7.5.0|>=7.3.0|>=7.2.0']
# ujson -> libstdcxx-ng[version='>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0']
# google-pasta -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# ipython_genutils -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# python-dateutil -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# glib -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# blas -> llvm-openmp[version='>=9.0.1'] -> libstdcxx-ng[version='>=7.3.0']
# lazy-object-proxy -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# prompt-toolkit -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# colorama -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# aiohttp -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# python=3.8 -> libffi[version='>=3.2.1,<3.3.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.2.0']
# scipy -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# olefile -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# boto -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# jedi -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# isort -> python[version='>=3.6,<4.0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pyasn1 -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# werkzeug -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# backcall -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# cairo -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# importlib_metadata -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# libxml2 -> icu[version='>=68.1,<69.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=7.2.0']
# fsspec -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# requests -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# patchelf -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.4.0|>=7.2.0']
# distributed -> msgpack-python[version='>=0.6.0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pyrsistent -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# sphinxcontrib-htmlhelp -> python[version='>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# decorator -> python[version='>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# snowballstemmer -> python[version='>=2'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# async-timeout -> python[version='>=3.5.3'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# flake8 -> python[version='>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# py -> python[version='>=2.7'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# intervaltree -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# seaborn -> matplotlib-base[version='>=2.1.2'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# alabaster -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# backports.tempfile -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# wheel -> python[version='!=3.0,!=3.1,!=3.2,!=3.3,!=3.4'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# greenlet -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.2.0']
# tensorflow-datasets -> numpy -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=9.4.0|>=9.3.0|>=7.5.0|>=7.2.0|>=5.4.0']
# llvmlite -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pathtools -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# clyent -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# anaconda-client -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# cryptography -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# sqlalchemy -> greenlet!=0.4.17 -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# dill -> python[version='>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# transformers -> numpy -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=9.3.0|>=7.5.0|>=9.4.0|>=7.2.0|>=5.4.0']
# mkl-service -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# googleapis-common-protos -> protobuf[version='>=3.12.0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# tokenizers -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.2.0']
# iniconfig -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# argon2-cffi -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# jsonlines -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# conda-package-handling -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# defusedxml -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# grpcio -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=7.2.0']
# readline -> ncurses[version='>=6.2,<6.3.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=7.2.0']
# py-lief -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='>=4.9|>=9.4.0']
# oauthlib -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# numpydoc -> python[version='>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# psutil -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# cudatoolkit -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
# tokenizers -> libstdcxx-ng[version='>=7.5.0|>=9.3.0|>=9.4.0']
# filelock -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# ply -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# tbb -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=7.2.0']
# setuptools -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pywavelets -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# sphinx -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# jupyterlab_pygments -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# grpcio -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=9.4.0']
# path -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# threadpoolctl -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# python-language-server -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pycodestyle -> python[version='2.7.*|>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# dask-core -> python[version='>=3.7'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# sqlite -> ncurses[version='>=6.2,<6.3.0a0'] -> libstdcxx-ng[version='>=7.2.0|>=7.5.0']
# future -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# tensorflow-base -> libstdcxx-ng[version='>=5.4.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pango -> cairo[version='>=1.16.0,<1.17.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=9.4.0|>=9.3.0|>=7.5.0|>=7.2.0']
# regex -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# contextlib2 -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# sortedcollections -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# cupti -> cudatoolkit[version='>=11.3,<11.4'] -> libstdcxx-ng[version='>=9.3.0']
# webencodings -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# multidict -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# tensorboard -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# imageio -> numpy -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=9.3.0|>=7.5.0|>=9.4.0|>=7.2.0']
# navigator-updater -> pyqt[version='>=5.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=7.2.0|>=9.3.0|>=9.4.0']
# prometheus_client -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# html5lib -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# cytoolz -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# requests-oauthlib -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# anaconda-navigator -> pyqt[version='>=5.6,<6.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=7.2.0|>=9.3.0|>=9.4.0']
# sip -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=7.2.0']
# jupyter_console -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# gmp -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=7.2.0']
# bkcharts -> numpy[version='>=1.7.1'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=9.4.0|>=9.3.0|>=7.5.0|>=7.2.0']
# icu -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=7.2.0']
# qtpy -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# cython -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=7.2.0']
# bottleneck -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# wrapt -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# toolz -> python[version='>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pyxdg -> python[version='>=3'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# joblib -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# matplotlib-base -> libstdcxx-ng[version='>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0']
# rope -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pyzmq -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0']
# sphinxcontrib-applehelp -> python[version='>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# locket -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# xlwt -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# zeromq -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# xmltodict -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# cffi -> libffi[version='>=3.4.2,<3.5.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# sphinxcontrib -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pygments -> python[version='>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# dask -> pandas[version='>=1.0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pytz -> python[version='>=3'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# gnutls -> gmp[version='>=6.1.2,<7.0a0'] -> libstdcxx-ng[version='>=7.2.0']
# gnutls -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0']
# yaml -> libstdcxx-ng[version='>=7.3.0']
# gast -> python[version='>=3.4'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# lz4-c -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0']
# asn1crypto -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# python_abi -> python=3.9 -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# mecab-python3 -> python[version='>=3.8,<3.9.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.4.0|>=7.2.0']
# qt -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=7.5.0|>=9.3.0']
# matplotlib-base -> kiwisolver[version='>=1.0.1'] -> libstdcxx-ng[version='>=4.9|>=7.2.0']
# astropy -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# libcurl -> krb5[version='>=1.19.2,<1.20.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=7.2.0']
# zope.interface -> python[version='>=3.6,<3.7.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# curl -> libstdcxx-ng[version='>=4.9']
# mkl_random -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=7.5.0|>=9.3.0']
# pyasn1-modules -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pandocfilters -> python[version='!=3.0,!=3.1,!=3.2,!=3.3'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# parso -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# path.py -> python[version='>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# backports -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# rtree -> libspatialindex[version='>=1.9.3,<1.9.4.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=9.3.0|>=7.5.0|>=9.4.0|>=7.2.0']
# matplotlib -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# flask -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# pyflakes -> python[version='2.7.*|>=3.5'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# ipykernel -> debugpy[version='>=1,<2.0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# tensorboard -> grpcio[version='>=1.24.3'] -> libstdcxx-ng[version='>=4.9|>=7.5.0|>=9.3.0|>=9.4.0']
# packaging -> python[version='>=3.6'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# conda-verify -> python[version='>=3.7,<3.8.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# hdf5 -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=7.2.0']
# h5py -> hdf5[version='>=1.12.1,<1.12.2.0a0'] -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# sphinxcontrib-websupport -> python -> libstdcxx-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# ...
#
# Package jupyter_console conflicts for:
# anaconda==2020.11 -> jupyter_console==6.2.0=py_0
# jupyter -> jupyter_console
# anaconda==2020.11 -> jupyter==1.0.0=py37_7 -> jupyter_console
#
# Package gst-plugins-base conflicts for:
# pyqt -> qt[version='>=5.12.9,<5.13.0a0'] -> gst-plugins-base[version='>=1.12.2,<1.13.0a0|>=1.12.4,<1.13.0a0|>=1.14.0,<1.15.0a0|>=1.14.4,<1.15.0a0|>=1.18.3,<1.19.0a0|>=1.12.5,<1.13.0a0']
# anaconda==2020.11 -> qt==5.9.7=h5867ecd_1 -> gst-plugins-base[version='>=1.14.0,<1.15.0a0']
# qt -> gst-plugins-base[version='>=1.12.2,<1.13.0a0|>=1.12.4,<1.13.0a0|>=1.12.5,<1.13.0a0|>=1.14.4,<1.15.0a0|>=1.18.3,<1.19.0a0|>=1.14.0,<1.15.0a0']
# anaconda==2020.11 -> gst-plugins-base==1.14.0=hbbd80ab_1
#
# Package appdirs conflicts for:
# scikit-image -> pooch[version='>=1.3.0'] -> appdirs
# prometheus_client -> twisted -> appdirs[version='>=1.4.0']
#
# Package ninja conflicts for:
# torchvision -> pytorch -> ninja
# pytorch -> ninja
# transformers -> pytorch -> ninja
#
# Package helpdev conflicts for:
# spyder -> qdarkstyle[version='>=2.8,<3.0'] -> helpdev[version='>=0.6.10']
# qdarkstyle -> helpdev[version='>=0.6.10']
#
# Package scikit-learn conflicts for:
# nltk -> scikit-learn
# anaconda==2020.11 -> scikit-learn==0.23.2[build='py38h0573a6f_0|py37h0573a6f_0']
#
# Package pywavelets conflicts for:
# anaconda==2020.11 -> pywavelets==1.1.1[build='py38h7b6447c_2|py37h7b6447c_2']
# scikit-image -> pywavelets[version='>=0.4.0']
# anaconda==2020.11 -> scikit-image==0.17.2=py37hdf5156a_0 -> pywavelets[version='>=0.4.0']
#
# Package watchdog conflicts for:
# anaconda==2020.11 -> watchdog==0.10.3[build='py37_0|py38_0']
# anaconda==2020.11 -> spyder==4.1.5=py37_0 -> watchdog
# spyder -> watchdog[version='>=0.10.3|>=0.10.3,<2.0.0']
#
# Package libvorbis conflicts for:
# qt -> gst-plugins-base[version='>=1.18.3,<1.19.0a0'] -> libvorbis[version='>=1.3.7,<1.4.0a0']
# gst-plugins-base -> libvorbis[version='>=1.3.7,<1.4.0a0']
#
# Package googleapis-common-protos conflicts for:
# tensorflow-metadata -> googleapis-common-protos[version='>=1.52.0,<2']
# tensorflow-datasets -> tensorflow-metadata -> googleapis-common-protos[version='>=1.52.0,<2']
#
# Package jupyterlab conflicts for:
# anaconda==2020.11 -> jupyterlab==2.2.6=py_0
# _ipyw_jlab_nb_ext_conf -> jupyterlab
#
# Package jupyter-packaging conflicts for:
# jupyterlab_server -> jupyter_server[version='>=1.4,<2'] -> jupyter-packaging[version='>=0.9,<1.0']
# jupyterlab_server -> jupyter-packaging[version='>=0.9,<2']
#
# Package async-timeout conflicts for:
# google-auth -> aiohttp[version='>=3.6.2,<4.0.0dev'] -> async-timeout[version='<4.0,>=3.0|>=3.0,<4.0|>=1.2,<3.0|>=1.2.0']
# aiohttp -> async-timeout[version='<4.0,>=3.0|>=3.0,<4.0|>=1.2,<3.0|>=1.2.0']
#
# Package s3fs conflicts for:
# distributed -> s3fs[version='>=0.0.6|>=0.0.7|>=0.0.8']
# dask -> distributed[version='>=1.16.0'] -> s3fs[version='>=0.0.6|>=0.0.7|>=0.0.8']
#
# Package pyxdg conflicts for:
# spyder -> pyxdg[version='>=0.26']
# anaconda==2020.11 -> pyxdg==0.27=pyhd3eb1b0_0
# anaconda==2020.11 -> spyder==4.1.5=py37_0 -> pyxdg[version='>=0.26']
#
# Package xorg-libsm conflicts for:
# qt -> xorg-libsm
# qt -> xorg-libxt -> xorg-libsm=1.2
#
# Package cached-property conflicts for:
# h5py -> cached-property
# tensorflow-base -> h5py[version='>=3.1.0'] -> cached-property
#
# Package keyring conflicts for:
# anaconda==2020.11 -> keyring==21.4.0[build='py37_1|py38_1']
# anaconda==2020.11 -> spyder==4.1.5=py37_0 -> keyring
# spyder -> keyring[version='>=17.0.0']
#
# Package pycrypto conflicts for:
# anaconda==2020.11 -> pycrypto==2.6.1=py37h7b6447c_10
# conda-build -> pycrypto
#
# Package xorg-libice conflicts for:
# qt -> xorg-libice
# qt -> xorg-libsm -> xorg-libice=1.0The following specifications were found to be incompatible with your system:
#
#   - feature:/linux-64::__glibc==2.28=0
#   - feature:|@/linux-64::__glibc==2.28=0
#   - aiohttp -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - argon2-cffi -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - astropy -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - bitarray -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - blas -> libgfortran-ng -> __glibc[version='>=2.17']
#   - blosc -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - bottleneck -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - brotlipy -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - bzip2 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - c-ares -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cairo -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cffi -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - conda-package-handling -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cryptography -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cudatoolkit -> __glibc[version='>=2.17,<3.0.a0']
#   - cudatoolkit -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cudnn -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - curl -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cython -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - cytoolz -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - dbus -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - expat -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - fastcache -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - ffmpeg -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - fontconfig -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - freetype -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - fribidi -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - gevent -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - glib -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - gmp -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - gmpy2 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - gnutls -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - graphite2 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - greenlet -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - grpcio -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - gst-plugins-base -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - gstreamer -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - h5py -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - harfbuzz -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - hdf5 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - icu -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - jbig -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - jpeg -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - kiwisolver -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - krb5 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - lame -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - lazy-object-proxy -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - lcms2 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libarchive -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libcurl -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libedit -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libffi -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libgcc-ng -> __glibc[version='>=2.17']
#   - libgfortran-ng -> __glibc[version='>=2.17']
#   - libiconv -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libidn2 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - liblief -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libllvm10 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libpng -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libprotobuf -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libsodium -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libspatialindex -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libssh2 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libstdcxx-ng -> __glibc[version='>=2.17']
#   - libtasn1 -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - libtiff -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libtool -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - libunistring -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libuuid -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libuv -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libxcb -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libxml2 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - libxslt -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - llvmlite -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - lxml -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - lz4-c -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - lzo -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - markupsafe -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - matplotlib -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - matplotlib-base -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - mecab-python3 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - mistune -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - mkl-service -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - mkl_fft -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - mkl_random -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - mpc -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - mpfr -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - msgpack-python -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - multidict -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - ncurses -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - nettle -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - ninja -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - numba -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - numexpr -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - numpy -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - numpy-base -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - openh264 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - openssl -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pandas -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pango -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - patchelf -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - pcre -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pillow -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pixman -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - protobuf -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - psutil -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - py-lief -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pycosat -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pycurl -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pyodbc -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pyqt -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - pyrsistent -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pytables -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - python=3.8 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pytorch -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - pywavelets -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pyyaml -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - pyzmq -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - qt -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - readline -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - regex -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - ripgrep -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - ruamel_yaml -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - scikit-image -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - scikit-learn -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - scipy -> libgfortran-ng -> __glibc[version='>=2.17']
#   - sip -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - sqlalchemy -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - sqlite -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - statsmodels -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - tbb -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - tensorboard -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - tensorflow -> libgcc-ng[version='>=5.4.0'] -> __glibc[version='>=2.17']
#   - tensorflow-base -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - tensorflow-metadata -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - tifffile -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - tk -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - tokenizers -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - torchvision -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - tornado -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - transformers -> pytorch -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - ujson -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - unixodbc -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - wrapt -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - xz -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - yaml -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - yarl -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - zeromq -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - zlib -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - zope.interface -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - zstd -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#
# Your installed version is: 2.28
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from transformers import BertForMaskedLM, BertConfig, BertTokenizer
import mecab
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-401d562c1f2e> in <module>
#       1 import torch
#       2 from transformers import BertForMaskedLM, BertConfig, BertTokenizer
# ----> 3 import mecab
#
# ModuleNotFoundError: No module named 'mecab'
